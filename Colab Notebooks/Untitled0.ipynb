# %%
import cv2
import numpy as np
img = cv2.imread('lab1.jpg')
cv2.show('lab1.jpg,img')
c= (255/np.log(1+np.max(img)))
log_trx_img= c*np.log(1+img)
log_trx_img = np.array(log_trx_img,dtype=np.uint8)
cv2.imshow('outputImage',log_trx_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-2f3896f52e2f> in <cell line: 4>()
#       2 import numpy as np
#       3 img = cv2.imread('lab1.jpg')
# ----> 4 cv2.show('lab1.jpg,img')
#       5 c= (255/np.log(1+np.max(img)))
#       6 log_trx_img= c*np.log(1+img)
#
# AttributeError: module 'cv2' has no attribute 'show'
